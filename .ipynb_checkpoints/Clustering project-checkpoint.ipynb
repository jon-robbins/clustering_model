# %% [markdown]
# <img src = "https://github.com/barcelonagse-datascience/academic_files/raw/master/bgsedsc_0.jpg">
# $\newcommand{\bb}{\boldsymbol{\beta}}$
# $\DeclareMathOperator{\Gau}{\mathcal{N}}$
# $\newcommand{\bphi}{\boldsymbol \phi}$
# $\newcommand{\bx}{\boldsymbol{x}}$
# $\newcommand{\bu}{\boldsymbol{u}}$
# $\newcommand{\by}{\boldsymbol{y}}$
# $\newcommand{\whbb}{\widehat{\bb}}$
# $\newcommand{\hf}{\hat{f}}$
# $\newcommand{\tf}{\tilde{f}}$
# $\newcommand{\ybar}{\overline{y}}$
# $\newcommand{\E}{\mathbb{E}}$
# $\newcommand{\Var}{Var}$
# $\newcommand{\Cov}{Cov}$
# $\newcommand{\Cor}{Cor}$

# %% [markdown]
# ## Retail Customer Clustering
#
# ### Overview
# The dataset given is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts.
#
# ### Business Goal
# We aim to segment the Customers based on RFM so that the company can target its customers efficiently.
#
# The RFM analysis is a marketing technique used to quantitatively rank and group customers based on the recency, frequency and monetary total of their recent transactions to identify the best customers and perform targeted marketing campaigns.
#
# ### Data
#
# You are given a dataset: each row represents a transaction (so, if a given customer buys a t-shirt and socks you will have one row for the t-shirt and one row for the socks).
#
# + InvoiceNo: id of the invoice
# + StockCode: id of the given clothing
# + Description: description of the clothing item
# + Quantity: quantity purchased
# + InvoiceDate: date of the purchase
# + UnitPrice: unit price of the clothing item
# + CustomerID: id of the customer
# + Country: country of the customer
#
#
# You are asked to **develop a clustering algorithm** to be able to group clients based on their RFM:
#
# + Recency: days from their last purchase
# + Frecuency: how many times per month/week they buy
# + Monetary: how much is their average ticket
#
# ### Business questions
#
# 1. **How many groups of customers do we have**
# 2. **Which is their profile**
#
#
# ### Steps
#
# You can follow those **steps** :
# 1. *Explore* and understand the dataset.
# 2. Data Cleansing
# 3. Data preparation (RFM)
# 4. Assess number of clusters
# 5. Build clusters
# 6. Profiling of each cluster: how often they buy, how much, are them a high value group or a low value?

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# 1. Loading and cleaning data

# %%
df= pd.read_csv('retail_data.csv',sep=',',encoding= 'unicode_escape')
# today=
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
import datetime
import time
# today=datetime.datetime(year=2022,month=12,day=1)
# datetime.date.fromtimestamp(time.time())
# datetime.datetime.strptime('01-12-2010 08:26','%d-%m-%Y %H:%M')
df.InvoiceDate=pd.to_datetime(df['InvoiceDate'],format='%d-%m-%Y %H:%M')	
# df['recency']=df['InvoiceDate'].apply(lambda x :(today-datetime.datetime.strptime(x.split(' ')[0],'%d-%m-%Y')).days	 )
df['diff']=max(df.InvoiceDate)-df.InvoiceDate

# %%
df['Amount']=df.Quantity*df.UnitPrice

# %%
# #splitting up date
# df['day']=df['InvoiceDate'].apply(lambda x : x.split('-')[0])
# df['month']=df['InvoiceDate'].apply(lambda x : x.split('-')[1])
# df['year']=df['InvoiceDate'].apply(lambda x : x.split('-')[2].split(' ')[0])
# df['hour']=df['InvoiceDate'].apply(lambda x : x.split('-')[2].split(' ')[1].split(':')[0])
# df['min']=df['InvoiceDate'].apply(lambda x : x.split('-')[2].split(' ')[1].split(':')[1])
# df.drop('InvoiceDate',inplace=True,axis=1)

# df.head()

# %%
#preliminary analysis of data
def IQROutlier(x):
    # x is the array of data you want to check for outliers using the IQR
    Q1 = np.nanpercentile(x, 25)
    Q3 = np.nanpercentile(x, 75)
    IQR = Q3 - Q1
    lowerbound = Q1 - IQR*1.5
    upperbound = Q3 + IQR*1.5

    outliers = []
    for i in x:
        if i > upperbound or i < lowerbound:
            outliers.append(1)
        else:
            outliers.append(0)
    return outliers

# %%
print(df.isnull().sum())
df.dropna(axis=0,how='any',subset=['CustomerID'],inplace=True)
df.isnull().any().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# diff                0
# Amount              0
# dtype: int64
# 0

# %%
df[df.duplicated(subset=['CustomerID','InvoiceNo','StockCode'])].sort_values(['InvoiceNo','CustomerID'])
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 125       536381     71270                  PHOTO CLIP LINE         3
# 498       536409    90199C  5 STRAND GLASS NECKLACE CRYSTAL         1
# 502       536409     85116  BLACK CANDELABRA T-LIGHT HOLDER         5
# 517       536409     21866      UNION JACK FLAG LUGGAGE TAG         1
# 525       536409    90199C  5 STRAND GLASS NECKLACE CRYSTAL         2
# ...          ...       ...                              ...       ...
# 479869   C577227         D                         Discount        -1
# 491733   C578073         M                           Manual       -36
# 520134   C580263         M                           Manual       -16
# 529981   C580764     22667            RECIPE BOX RETROSPOT        -12
# 531800   C580968     23534           WALL ART STOP FOR TEA         -3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df=df[df['Quantity']>0]

# %%
monetary=df.groupby('CustomerID')['Amount'].sum()
monetary=monetary.reset_index()
monetary.head(5)
# Out:
#    CustomerID    Amount
# 0     12346.0  77183.60
# 1     12347.0   4310.00
# 2     12348.0   1797.24
# 3     12349.0   1757.55
# 4     12350.0    334.40

# %%
frequency=df.groupby('CustomerID')['InvoiceNo'].count()
frequency=frequency.reset_index()
frequency.head(5)
# Out:
#    CustomerID  InvoiceNo
# 0     12346.0          1
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
recency=df.groupby('CustomerID')['diff'].min()
recency=recency.reset_index()
recency['diff']=recency['diff'].dt.days
recency.head(5)
# Out:
#    CustomerID  diff
# 0     12346.0   325
# 1     12347.0     1
# 2     12348.0    74
# 3     12349.0    18
# 4     12350.0   309

# %%
rfm=pd.merge(recency,frequency,on='CustomerID',how='inner')
rfm=pd.merge(rfm,monetary,on='CustomerID',how='inner')
# rfm

# %%
rfm.columns=['CustomerID','Recency','Frequency','Monetary']
rfm.columns
# Out:
# Index(['CustomerID', 'Recency', 'Frequency', 'Monetary'], dtype='object')

# %%
scaler=StandardScaler()
rfm_normalized=rfm[['Recency','Frequency','Monetary']]
scaler.fit(rfm_normalized)
rfm_normalized=pd.DataFrame(scaler.fit_transform(rfm_normalized))
rfm_normalized.columns=['Recency','Frequency','Monetary']
rfm_normalized
# Out:
#        Recency  Frequency  Monetary
# 0     2.334858  -0.396512  8.359634
# 1    -0.905199   0.394688  0.251046
# 2    -0.175186  -0.265374 -0.028546
# 3    -0.735196  -0.081781 -0.032963
# 4     2.174855  -0.326572 -0.191315
# ...        ...        ...       ...
# 4334  1.854850  -0.357171 -0.208429
# 4335  0.884833  -0.370285 -0.219531
# 4336 -0.845198  -0.348428 -0.208712
# 4337 -0.885199   2.903796  0.004572
# 4338 -0.495192  -0.094895 -0.024091
#
# [4339 rows x 3 columns]

# %%
# kmeans=KMeans(n_clusters=4,max_iter=50)
# kmeans.fit(rfm_normalized)
# Out:
# /home/djtom/bse/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# /home/djtom/bse/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# 0    3248
# 2    1080
# 3       7
# 1       4
# Name: pred_cluster, dtype: int64

# %%
distortions=[]
range_n_clusters=list(range(2,15))
for n in range_n_clusters:
    kmeans=KMeans(n_clusters=n,max_iter=50)
    kmeans.fit(rfm_normalized)
    distortions.append(kmeans.inertia_)

plt.figure(figsize=(16,8))
plt.plot(range_n_clusters, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
#taking ideal number of clusters as 6
kmeans=KMeans(n_clusters=6,max_iter=50)
kmeans.fit(rfm_normalized)
rfm_normalized['pred_cluster'] = kmeans.predict(rfm_normalized)
rfm_normalized['pred_cluster'].value_counts()
# Out:
# 1    2923
# 0    1056
# 4     338
# 5      14
# 3       4
# 2       4
# Name: pred_cluster, dtype: int64

# %%
# fig, axes = plt.subplots(1, 2, figsize=(16,8))
# # axes[0].scatter(df_copy['x1'], df_copy['x2'], c=df_copy['true_cluster'])
# axes[1].scatter(df_copy['x1'], df_copy['x2'], c=rfm_normalized['pred_cluster'], cmap=plt.cm.Set1)
# axes[0].set_title('Actual', fontsize=18)
# axes[1].set_title('K_Means', fontsize=18)
from mpl_toolkits.mplot3d import Axes3D
# plt.rcParams['figure.figsize']=(25,25)
fig=plt.figure(1)
# plt.clf()
ax=fig.add_subplot(projection='3d')
# plt.cla()
ax.scatter(rfm_normalized['Frequency'],rfm_normalized['Recency'],rfm_normalized['Monetary'],
c=rfm_normalized['pred_cluster'],s=200,cmap='spring',alpha=0.5,edgecolor='darkgrey')
ax.set_xlabel('Frequency',fontsize=16)
ax.set_ylabel('Recency',fontsize=16)
ax.set_zlabel('Monetary',fontsize=16)
plt.show()

# %%
sns.boxplot(x='pred_cluster',y='Monetary',data=rfm_normalized)
# Out:
# <AxesSubplot: xlabel='pred_cluster', ylabel='Monetary'>

# %%
sns.boxplot(x='pred_cluster',y='Recency',data=rfm_normalized)
# Out:
# <AxesSubplot: xlabel='pred_cluster', ylabel='Recency'>

# %%
sns.boxplot(x='pred_cluster',y='Frequency',data=rfm_normalized)
# Out:
# <AxesSubplot: xlabel='pred_cluster', ylabel='Frequency'>

# %%
sns.scatterplot(y='Monetary',x='Frequency',data=rfm_normalized, hue='pred_cluster')
# Out:
# <AxesSubplot: xlabel='Frequency', ylabel='Monetary'>

# %%
sns.scatterplot(y='Monetary',x='Recency',data=rfm_normalized, hue='pred_cluster')
# Out:
# <AxesSubplot: xlabel='Recency', ylabel='Monetary'>

# %%
sns.scatterplot(y='Monetary',x='Frequency',data=rfm_normalized, hue='pred_cluster')
# Out:
# <AxesSubplot: xlabel='Frequency', ylabel='Monetary'>

# %%
sns.scatterplot(x='Recency',y='Frequency',data=rfm_normalized, hue='pred_cluster')
# Out:
# <AxesSubplot: xlabel='Recency', ylabel='Frequency'>

# %% [markdown]
# For Model 2, let us use silhouette score analysis

# %%
for n in range_n_clusters:
    kmeans=KMeans(n_clusters=n,max_iter=50)
    kmeans.fit(rfm_normalized)
    cluster_labels=kmeans.labels_
    #score
    silhouette_avg=silhouette_score(rfm_normalized,cluster_labels)
    print(f"For n_clusters={n},the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2,the silhouette score is 0.712819349597602
# For n_clusters=3,the silhouette score is 0.687084286745709
# For n_clusters=4,the silhouette score is 0.7014554752664035
# For n_clusters=5,the silhouette score is 0.7010116846866775
# For n_clusters=6,the silhouette score is 0.7059010446448569
# For n_clusters=7,the silhouette score is 0.6453836709028784
# For n_clusters=8,the silhouette score is 0.47388763326148287
# For n_clusters=9,the silhouette score is 0.4724989543393502
# For n_clusters=10,the silhouette score is 0.47344762975652205
# For n_clusters=11,the silhouette score is 0.4624244990684713
# For n_clusters=12,the silhouette score is 0.46778533786303117
# For n_clusters=13,the silhouette score is 0.4580619677733773
# For n_clusters=14,the silhouette score is 0.4590593268609513

# %% [markdown]
# The best number of clusters is equal to 6.

# %%
kmeans=KMeans(n_clusters=6,max_iter=50)
kmeans.fit(rfm_normalized)
rfm_normalized.loc[:,'CustomerID']=rfm['CustomerID']
rfm_normalized
# Out:
#        Recency  Frequency  Monetary  pred_cluster  CustomerID
# 0     2.334858  -0.396512  8.359634             5     12346.0
# 1    -0.905199   0.394688  0.251046             1     12347.0
# 2    -0.175186  -0.265374 -0.028546             1     12348.0
# 3    -0.735196  -0.081781 -0.032963             1     12349.0
# 4     2.174855  -0.326572 -0.191315             0     12350.0
# ...        ...        ...       ...           ...         ...
# 4334  1.854850  -0.357171 -0.208429             0     18280.0
# 4335  0.884833  -0.370285 -0.219531             0     18281.0
# 4336 -0.845198  -0.348428 -0.208712             1     18282.0
# 4337 -0.885199   2.903796  0.004572             4     18283.0
# 4338 -0.495192  -0.094895 -0.024091             1     18287.0
#
# [4339 rows x 5 columns]

# %%
fig=plt.figure(1)
# plt.clf()
ax=fig.add_subplot(projection='3d')
# plt.cla()
ax.scatter(rfm_normalized['Frequency'],rfm_normalized['Recency'],rfm_normalized['Monetary'],
c=rfm_normalized['pred_cluster'],s=200,cmap='spring',alpha=0.5,edgecolor='darkgrey')
ax.set_xlabel('Frequency',fontsize=16)
ax.set_ylabel('Recency',fontsize=16)
ax.set_zlabel('Monetary',fontsize=16)
plt.show()
